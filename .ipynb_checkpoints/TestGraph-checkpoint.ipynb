# %% [markdown]
# # Testing View Graph
#
# ## Creating View Graph

# %%
# Parameters
from Parameters import Parameters

# Utitlies for mathematical calculation, isovist and visualization
from Isovist import Isovist
from Plotter import Plotter
from Utility import Utility

# Container -> Environment -> View Graph
from Container import Container
from Environment import IndoorEnvironment
from ViewGraph import ViewGraph

# %%
Parameters.set_env("real")  # this can be set to "basic" environment, "hypo" environment as well
Parameters.print_info()
# Out:
# --------------------------------------
# Real-world environment is active
#
# Static Variables:
# 	epsilon: 0.01
# 	precision: 2
# 	alpha: 40
# 	fov: 160
# 	min_area: 1000000
# 	max_area: 1000000
# 	door_weight: 50
# 	turn_weight: 0.05
# --------------------------------------

# %%
def read_env():
    # Basic environment
    if Parameters.basic:
        address = 'envs/basic/'
        pfiles = ['t_bound.geojson']
        hfiles = [None]
        dfiles = ['t_doors.geojson']
        dpfiles = [None]
        lfiles = ['t_landmarks.geojson']
        # create an indoor environment
        ie = IndoorEnvironment(address, pfiles, hfiles, dfiles, dpfiles, lfiles)

    # Hypo environment
    elif Parameters.hypo:
        address = 'envs/hypo/'
        pfiles = ['hypo_env.geojson']
        hfiles = ['hypo_holes.geojson']
        dfiles = ['hypo_doors.geojson']
        dpfiles = ['hypo_dpoints.geojson']
        lfiles = ['hypo_landmarks.geojson']
        # create an indoor environment
        ie = IndoorEnvironment(address, pfiles, hfiles, dfiles, dpfiles, lfiles)

    # MC5 real world environment
    else:
        address = 'envs/mc-floor-5/'
        pfiles, hfiles, dfiles, dpfiles, lfiles = IndoorEnvironment.reformat(
            address, 'containers.geojson', 'doors.geojson', 'landmarks.geojson')
        # create an indoor environment
        ie = IndoorEnvironment('', pfiles, hfiles, dfiles, dpfiles, lfiles)
    return ie

ie = read_env()
# Out:
# environment files -- count is valid
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)
# reading GeoJSON files (boundary, holes, doors and decision points)

# %%
# create view graph
vgs, isovist_objects = ie.construct_view_graph()
# Out:
# *******************************************
# Analyzing: Emergency Stairs
# Container environment is valid: True
# region initial : 1
# regions : 1 -- 1
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 12
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Women Toilet
# Container environment is valid: True
# region initial : 3
# regions : 4 -- 3
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 49
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Disabled Toilet
# Container environment is valid: True
# region initial : 1
# regions : 1 -- 1
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 2
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Men Toilet
# Container environment is valid: True
# region initial : 1
# regions : 1 -- 1
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 2
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Corridor
# Container environment is valid: True
# region initial : 21
# regions : 21 -- 21
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 319
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Active Hub
# Container environment is valid: True
# region initial : 43
# regions : 50 -- 43
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 537
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Stairs to Lower Floors
# Container environment is valid: True
# region initial : 1
# regions : 1 -- 1
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 2
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: Ngi-a Djerring Gat-ith
# Container environment is valid: True
# region initial : 1
# regions : 1 -- 1
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 72
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)
#
# *******************************************
# Analyzing: UX Lab
# Container environment is valid: True
# region initial : 16
# regions : 20 -- 16
# calculating the visibility signatures...
# calculating adjacency matrix for regions
# finding regions that contains doors/gateways and decision points
# decompose views
# len: 211
# constructing view graph for regions
# calculating all spatial relationships visible in each view
# Adding actions to views (nodes)
# Adding actions to view relations (edges)

# %% [markdown]
# ## Testing View Graph
#
# ### Connectivity
# Is the resulted view graph connected? If not, what are the components and why there is connectivity issue?

# %%
import networkx as nx

for idx, vg in enumerate(vgs):
    print('id: {2} -- {0} is connected? {1}'.format(vg.name, nx.is_strongly_connected(vg.rviewgraph), idx))
# Out:
# id: 0 -- Emergency Stairs is connected? True
# id: 1 -- Women Toilet is connected? True
# id: 2 -- Disabled Toilet is connected? True
# id: 3 -- Men Toilet is connected? True
# id: 4 -- Corridor is connected? True
# id: 5 -- Active Hub is connected? False
# id: 6 -- Stairs to Lower Floors is connected? True
# id: 7 -- Ngi-a Djerring Gat-ith is connected? True
# id: 8 -- UX Lab is connected? False

# %% [markdown]
# Two disconnected regions: *Active Hub* and *UX Lab*

# %%
def test_components(vg, isovist_object):
    main_components = []
    components = nx.strongly_connected_components(vg.rviewgraph)
    plotter = Plotter()
    plotter.add_isovist(isovist_object)
    for comp in components:
        print(len(comp))
        if len(comp) < 50:
            print(list(comp))
            plotter.add_views([vg.rviews[int(vid.split('-V')[1])] for vid in list(comp)])
        main_components.append(comp)
    plotter.show()
    
    print('Main components: {}'.format(len(main_components)))
    plotter = Plotter()
    plotter.add_isovist(isovist_object)
    for comp in main_components:
        plotter.add_views([vg.rviews[int(vid.split('-V')[1])] for vid in list(comp)])
    plotter.show()

# %%
# test case: Active Hub
vg_ah = vgs[5]
isovist_object_ah = isovist_objects[5]
test_components(vg_ah, isovist_object_ah)
# Out:
# 2205
# 1
# ['Active Hub-V646']
# 1
# ['Active Hub-V645']
# 1
# ['Active Hub-V656']
# 1
# ['Active Hub-V655']
# 1
# ['Active Hub-V654']
# 1
# ['Active Hub-V653']
# 1
# ['Active Hub-V652']
# 1
# ['Active Hub-V651']
# 1
# ['Active Hub-V650']
# 1
# ['Active Hub-V649']
# 1
# ['Active Hub-V648']
# 1
# ['Active Hub-V664']
# 1
# ['Active Hub-V663']
# 1
# ['Active Hub-V662']
# 1
# ['Active Hub-V661']
# 1
# ['Active Hub-V660']
# 1
# ['Active Hub-V659']
# 1
# ['Active Hub-V668']
# 1
# ['Active Hub-V667']
# 1
# ['Active Hub-V666']
# 1
# ['Active Hub-V673']
# 1
# ['Active Hub-V672']
# 1
# ['Active Hub-V671']
# 1
# ['Active Hub-V670']
# 10
# ['Active Hub-V657', 'Active Hub-V665', 'Active Hub-V643', 'Active Hub-V658', 'Active Hub-V644', 'Active Hub-V647', 'Active Hub-V2249', 'Active Hub-V2250', 'Active Hub-V642', 'Active Hub-V669']
# 1
# ['Active Hub-V814']
# 1
# ['Active Hub-V813']
# 1
# ['Active Hub-V812']
# 1
# ['Active Hub-V811']
# 1
# ['Active Hub-V810']
# 1
# ['Active Hub-V809']
# 1
# ['Active Hub-V808']
# 1
# ['Active Hub-V807']
# 1
# ['Active Hub-V806']
# 1
# ['Active Hub-V805']
# 9
# ['Active Hub-V818', 'Active Hub-V802', 'Active Hub-V801', 'Active Hub-V804', 'Active Hub-V815', 'Active Hub-V800', 'Active Hub-V803', 'Active Hub-V817', 'Active Hub-V816']
# 1
# ['Active Hub-V1769']
# 1
# ['Active Hub-V1768']
# 1
# ['Active Hub-V1767']
# 1
# ['Active Hub-V1766']
# 1
# ['Active Hub-V1765']
# 1
# ['Active Hub-V1764']
# 1
# ['Active Hub-V1763']
# 1
# ['Active Hub-V1762']
# 1
# ['Active Hub-V1761']
# 1
# ['Active Hub-V1779']
# 1
# ['Active Hub-V1778']
# 1
# ['Active Hub-V1777']
# 1
# ['Active Hub-V1776']
# 1
# ['Active Hub-V1775']
# 1
# ['Active Hub-V1774']
# 1
# ['Active Hub-V1773']
# 1
# ['Active Hub-V1772']
# 1
# ['Active Hub-V1789']
# 1
# ['Active Hub-V1788']
# 1
# ['Active Hub-V1787']
# 1
# ['Active Hub-V1786']
# 1
# ['Active Hub-V1785']
# 1
# ['Active Hub-V1784']
# 1
# ['Active Hub-V1783']
# 1
# ['Active Hub-V1782']
# 1
# ['Active Hub-V1781']
# 5
# ['Active Hub-V1780', 'Active Hub-V1770', 'Active Hub-V1760', 'Active Hub-V1771', 'Active Hub-V1759']
# Main components: 64

# %%
# test case: UXLab
vg_ul = vgs[8]
isovist_object_ul = isovist_objects[8]
test_components(vg_ul, isovist_object_ul)
# Out:
# 784
# 4
# ['UX Lab-V505', 'UX Lab-V503', 'UX Lab-V504', 'UX Lab-V506']
# 1
# ['UX Lab-V513']
# 1
# ['UX Lab-V512']
# 1
# ['UX Lab-V511']
# 1
# ['UX Lab-V510']
# 1
# ['UX Lab-V509']
# 1
# ['UX Lab-V517']
# 1
# ['UX Lab-V516']
# 1
# ['UX Lab-V515']
# 1
# ['UX Lab-V520']
# 1
# ['UX Lab-V519']
# 1
# ['UX Lab-V522']
# 1
# ['UX Lab-V525']
# 1
# ['UX Lab-V524']
# 1
# ['UX Lab-V531']
# 1
# ['UX Lab-V530']
# 1
# ['UX Lab-V529']
# 1
# ['UX Lab-V528']
# 1
# ['UX Lab-V535']
# 1
# ['UX Lab-V534']
# 1
# ['UX Lab-V533']
# 1
# ['UX Lab-V539']
# 1
# ['UX Lab-V538']
# 1
# ['UX Lab-V537']
# 1
# ['UX Lab-V541']
# 11
# ['UX Lab-V527', 'UX Lab-V526', 'UX Lab-V536', 'UX Lab-V508', 'UX Lab-V507', 'UX Lab-V540', 'UX Lab-V518', 'UX Lab-V514', 'UX Lab-V521', 'UX Lab-V523', 'UX Lab-V532']
# 1
# ['UX Lab-V825']
# 1
# ['UX Lab-V829']
# 1
# ['UX Lab-V828']
# 1
# ['UX Lab-V827']
# 3
# ['UX Lab-V823', 'UX Lab-V824', 'UX Lab-V826']
# Main components: 32

# %%
def ill_shaped(r, min_area=300):
    if r.area/shapely.geometry.box(*r.bounds).area > 0.05 and r.area > min_area:
        return False
    return True
